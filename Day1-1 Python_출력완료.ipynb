# %% [markdown]
# <a href="https://colab.research.google.com/github/younggon2/Education/blob/master/Day1-1%20Python_%EC%B6%9C%EB%A0%A5%EC%99%84%EB%A3%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # 기초 파이썬 프로그래밍 이해
#
#
# *   변수 선언, 입출력
# *   자료형 : int, float, string, bool
# *   자료구조 : list, tuple, set, dict
# *   제어문 : if, while, for
# *   함수
# *   클래스
# *   iterator, generator

# %% [markdown]
# ## 변수 선언, 입출력

# %%
number = 1
string = 'abc'

print(1)
print(number)
print('abc')
print(string)
# Out:
# 1
# 1
# abc
# abc

# %% [markdown]
# ## 자료형 : int, float, string, bool

# %%
var_int = 1
var_float = 2.1
var_string = 'abc'
var_bool = True

print(var_int, var_float, var_string, var_bool)
# Out:
# 1 2.1 abc True

# %%
# 자료형은 다른 자료형으로 변환할 수 있다.
## int <-> float
var_int = int(1.1)
var_float = float(10)
print(var_int, var_float)
# Out:
# 1 10.0

# %%
## string은 다른 자료형으로 변환 불가능
## 하지만 숫자를 string으로는 변환 가능
var_string1 = str(1.0)
print(var_string1)
# var_string2 = int('abc')
# print(var_string2)
# Out:
# 1.0

# %%
## bool은 0 혹은 False는 False
## 나머지는 전부 True
print(bool(-1))
# Out:
# True

# %% [markdown]
# ## 자료구조 : list, tuple, set, dict

# %%
# list는 추가 및 삭제 가능, slicing 가능
# 자료형에 관계없이 모두 설정 가능
ex_list = [1, 2, 'a', True]
# ex_list = list([1, 2, 'a', True])
print(ex_list)
# Out:
# [1, 2, 'a', True]

# %%
print('\nindexing')
print(ex_list[1])
print('\nslicing')
print(ex_list[1:3])
# Out:
# indexing
# 2
#
# slicing
# [2, 'a']

# %%
print('\n추가')
ex_list.append('new')
print(ex_list)
ex_list += ['new1']
print(ex_list)
# Out:
# 추가
# [1, 2, 'a', True, 'new']
# [1, 2, 'a', True, 'new', 'new1']

# %%
print('\n반복')
ex_list *= 2
print(ex_list)
# Out:
# 반복
# [1, 2, 'a', True, 'new', 'new1', 1, 2, 'a', True, 'new', 'new1']

# %%
print('\n길이')
print(len(ex_list))
# Out:
# 길이
# 12

# %%
print('\n제거')
ex_list.pop()
print(ex_list)
# Out:
# 제거
# [1, 2, 'a', True, 'new', 'new1', 1, 2, 'a', True, 'new']

# %%
print('\n정렬')
ex_list = [1, 3, 2, 9, 5]
ex_list.sort()
print(ex_list)
# Out:
# 정렬
# [1, 2, 3, 5, 9]

# %%
print('\n뒤집기')
ex_list.reverse()
print(ex_list)
# print(ex_list[::-1])
# Out:
# 뒤집기
# [9, 5, 3, 2, 1]

# %%
print('\n위치 반환')
print(ex_list.index(2))
# Out:
# 위치 반환
# 3

# %%
# 2D list는 불가능하지만, list안에 list를 선언하여(2중 리스트) 2D list처럼 사용 가능
print('\n2중 리스트')
ex_list_2 = [[1, 2, 3], [4, 5]]
print(ex_list_2)
print(ex_list_2[0][1], ex_list_2[1][1])
# Out:
# 2중 리스트
# [[1, 2, 3], [4, 5]]
# 2 5

# %%
# tuple은 생성 이후에 추가 및 삭제 불가능, slicing 가능
# 자료형에 관계없이 모두 설정 가능
ex_tuple = (1, 2, 'a', True)
# ex_tuple = tuple([1, 2, 'a', True])
print(ex_tuple)
# Out:
# (1, 2, 'a', True)

# %%
print('\nindexing')
print(ex_tuple[1])
# Out:
# indexing
# 2

# %%
print('\nslicing')
print(ex_tuple[1:3])
# Out:
# slicing
# (2, 'a')

# %%
print('\n더하기')
print(ex_tuple + (3, 4, 5))
# Out:
# 더하기
# (1, 2, 'a', True, 3, 4, 5)

# %%
print('\n곱하기')
print(ex_tuple * 2)
# Out:
# 곱하기
# (1, 2, 'a', True, 1, 2, 'a', True)

# %%
print('\n길이')
print(len(ex_tuple))
# Out:
# 길이
# 4

# %%
# set은 집합으로 중복된 성분 제거
# 합집합, 차집합, 교집합 등 연산 가능
ex_set = set([1, 1, 2, 3, 4, 5, 5])
print('ex_set :', ex_set)

ex_set1 = set([4, 5, 7, 7, 8, 9])
print('ex_set1 :', ex_set1)

print('\n합집합')
print(ex_set | ex_set1)
print(ex_set.union(ex_set1))

print('\n차집합')
print(ex_set - ex_set1)
print(ex_set.difference(ex_set1))

print('\n교집합')
print(ex_set & ex_set1)
print(ex_set.intersection(ex_set1))
# Out:
# ex_set : {1, 2, 3, 4, 5}
# ex_set1 : {4, 5, 7, 8, 9}
#
# 합집합
# {1, 2, 3, 4, 5, 7, 8, 9}
# {1, 2, 3, 4, 5, 7, 8, 9}
#
# 차집합
# {1, 2, 3}
# {1, 2, 3}
#
# 교집합
# {4, 5}
# {4, 5}

# %%
# dict는 key, value로 구성
ex_dict = {'name':'pey', 'phone':'0119993323', 'birth': '1118'}
print(ex_dict)
# Out:
# {'name': 'pey', 'phone': '0119993323', 'birth': '1118'}

# %%
print('\n추가')
ex_dict['age'] = 18
print(ex_dict)
# Out:
# 추가
# {'name': 'pey', 'phone': '0119993323', 'birth': '1118', 'age': 18}

# %%
print('\n삭제')
del ex_dict['phone']
print(ex_dict)
# Out:
# 삭제
# {'name': 'pey', 'birth': '1118', 'age': 18}

# %%
print('\nkey list')
print(ex_dict.keys())
# Out:
# key list
# dict_keys(['name', 'birth', 'age'])

# %%
print('\nvalue list')
print(ex_dict.values())
# Out:
# value list
# dict_values(['pey', '1118', 18])

# %%
print('\nkey, value 쌍')
print(ex_dict.items())
# Out:
# key, value 쌍
# dict_items([('name', 'pey'), ('birth', '1118'), ('age', 18)])

# %%
print('\nkey로 value 얻기')
print(ex_dict.get('name'))
print(ex_dict['name'])
# Out:
# key로 value 얻기
# pey
# pey

# %%
print('\n특정 key가 dict 안에 있는지 확인')
print('birth' in ex_dict)
print('phone' in ex_dict)
# Out:
# 특정 key가 dict 안에 있는지 확인
# True
# False

# %% [markdown]
# ## 제어문 : if, while, for

# %%
# if : 조건문
## 주어진 조건에 부합하면 실행, 그렇지 않으면 통과
a = 1
if a > 0:
  print('a is positive value')
elif a == 0:
  print('a is zero')
else:
  print('a is negative value')
# Out:
# a is positive value

# %%
# while : 반복문
## 주어진 조건에 부합하면 반복, 그렇지 않으면 정지
a = 0
while a < 5:
  print(a)
  a += 1
print('end -> a : {}'.format(a))
# Out:
# 0
# 1
# 2
# 3
# 4
# end -> a : 5

# %%
# for : 반복문
## 주어진 횟수만큼 반복적용
print('횟수')
for i in range(5):
  print(i)
# Out:
# 횟수
# 0
# 1
# 2
# 3
# 4

# %%
## list, tuple, set도 적용 가능
print('\nlist, tuple, set')
ex_list = [1, 2, 3]
for i in ex_list:
  print(i)
# Out:
# list, tuple, set
# 1
# 2
# 3

# %%
# dict는 그대로 오거나 keys()를 사용하면 key, 
# values()를 사용하면 value,
# items()를 사용하면 key, value 모두 반환
print('\ndict')
ex_dict = {'a': 1, 'b': 2, 'c': 3}
for k in ex_dict:
  print(k)
# Out:
# dict
# a
# b
# c

# %% [markdown]
# ## 함수

# %%
# 반복되어 사용되는 기능을 하나의 함수로 선언하여 재사용

def sum(x, y=0):
  result = x + y
  return result

print(sum(1, 2))
print(sum(1))
# Out:
# 3
# 1

# %% [markdown]
# ## 클래스

# %%
# 연관성이 있는 함수들을 변수와 함께 지정
# 하나의 통합 기능을 클래스로 선언

class Arithmetic:
  def __init__(self, sum, subtract, multiply=True, divide=True):
    self.sum = sum
    self.subtract = subtract
    self.multiply = multiply
    self.divide = divide

  def get_sum(self, x, y):
    if self.sum:
      return x + y
    else:
      raise ValueError('Summation is not allowed.')

  def get_subtract(self, x, y):
    if self.subtract:
      return x - y
    else:
      raise ValueError('Subtraction is not allowed.')

  def get_multiply(self, x, y=5):
    if self.multiply:
      return x * y
    else:
      raise ValueError('Multiply is not allowed.')

  def get_divide(self, x, y):
    if self.divide:
      return x / y
    else:
      raise ValueError('Divide is not allowed.')

arithmetic_class = Arithmetic(sum=True, subtract=True, divide=False)
print(arithmetic_class.get_sum(1, 2))
print(arithmetic_class.get_subtract(1, 2))
print(arithmetic_class.get_multiply(2))
print(arithmetic_class.get_divide(6, 3))
# Out:
# 3
# -1
# 10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-9a1e2562d133> in <module>()
#      37 print(arithmetic_class.get_subtract(1, 2))
#      38 print(arithmetic_class.get_multiply(2))
# ---> 39 print(arithmetic_class.get_divide(6, 3))
#
# <ipython-input-61-9a1e2562d133> in get_divide(self, x, y)
#      31       return x / y
#      32     else:
# ---> 33       raise ValueError('Divide is not allowed.')
#      34
#      35 arithmetic_class = Arithmetic(sum=True, subtract=True, divide=False)
#
# ValueError: Divide is not allowed.

# %%
# 부모 클래스를 상속받아 사용할 수 있음!

class ArithmeticChild(Arithmetic):
  def __init__(self, power):
    super(ArithmeticChild, self).__init__(sum=True, subtract=True, multiply=True, divide=True)
    self.power = power

  def get_power(self, x, y):
    if self.power:
      return x ** self.get_sum(x, y)
    else:
      raise ValueError('Power is not allowed.')

arithmeticchild_class = ArithmeticChild(True)
print(arithmeticchild_class.get_power(2, 3))
# Out:
# 32

# %% [markdown]
# ## iterator, generator

# %%
# iterator : 반복자
# for 문에 들어갈 수 있으면 모두 iterator
# range, str, list, tuple, set, dict

for i in range(2):
  print(i)

for j in 'abc':
  print(j)
# Out:
# 0
# 1
# a
# b
# c

# %%
# generator : iterator를 생성해주는 함수
# return 대신 yield 사용
# 선언할 때마다 yield 실행

def mygenerator():
  yield 0
  yield 1
  yield 2

for i in mygenerator():
  print(i)
# Out:
# 0
# 1
# 2

# %% [markdown]
# # 파이썬 라이브러리
#
# *   numpy
# *   pandas
# *   matplotlib
# * opencv
# * scikit-learn

# %% [markdown]
# ## numpy

# %%
# numpy
import numpy as np
arr1 = np.array([1, 2, 3])
print('arr1 :\n', arr1)
arr2 = np.array([[1, 2, 3], [4, 5, 6]])
print('arr2 :\n', arr2)
arr3 = np.array([[1, 2], [4, 5]])
print('arr3 :\n', arr3)
# Out:
# arr1 :
#  [1 2 3]
# arr2 :
#  [[1 2 3]
#  [4 5 6]]
# arr3 :
#  [[1 2]
#  [4 5]]

# %%
# dimension-wise로 indexing & slicing 가능
print('indexing :', arr2[0,0], arr2[1,2])
print('slicing :', arr2[0], arr2[:,1])
# Out:
# indexing : 1 6
# slicing : [1 2 3] [2 5]

# %%
# 여러 선형대수 연산 가능
print('Diagonal matric :\n', np.diag(arr2))
print('Transpose :\n', np.transpose(arr2), arr2.T)
print('Dot product :\n', np.dot(arr2, arr2.T), arr2.dot(arr2.T))
print('Trace :\n', np.trace(arr2), arr2.trace())
print('Determinant :\n', np.linalg.det(arr3))
# Out:
# Diagonal matric :
#  [1 5]
# Transpose :
#  [[1 4]
#  [2 5]
#  [3 6]] [[1 4]
#  [2 5]
#  [3 6]]
# Dot product :
#  [[14 32]
#  [32 77]] [[14 32]
#  [32 77]]
# Trace :
#  6 6
# Determinant :
#  -2.9999999999999996

# %%
# 영행렬, 1로 초기화된 행렬, 단위 행렬
print('영행렬 :\n', np.zeros(shape=(2, 2), dtype=np.uint8))
print('1로 초기화된 행렬 :\n', np.ones(shape=(2, 2), dtype=np.uint8))
print('단위 행렬 :\n', np.eye(2, dtype=np.uint8))
# Out:
# 영행렬 :
#  [[0 0]
#  [0 0]]
# 1로 초기화된 행렬 :
#  [[1 1]
#  [1 1]]
# 단위 행렬 :
#  [[1 0]
#  [0 1]]

# %%
# 변형
print('reshape :\n', np.reshape(arr2, (3, 2)), np.reshape(arr2, (1, 6)))
print('flatten :\n', arr2.flatten())
# Out:
# reshape :
#  [[1 2]
#  [3 4]
#  [5 6]] [[1 2 3 4 5 6]]
# flatten :
#  [1 2 3 4 5 6]

# %%
# 순서
print('arange :\n', np.arange(5)) # start, end, interval
# Out:
# arange :
#  [0 1 2 3 4]

# %%
# random
# uniform, randint, ...
print('random :\n', np.random.random(size=(4,)))
print('permutation :\n', np.random.permutation(5))
# Out:
# random :
#  [0.42738535 0.6423499  0.53517545 0.68964584]
# permutation :
#  [2 3 4 0 1]

# %%
# 연결
# hstack, vstack, dstack, concatenate
print('hstack :\n', np.hstack((arr1, arr1)))
print('vstack :\n', np.vstack((arr1, arr1)))
print('stack :\n', np.stack((arr1, arr1), axis=0))
print('stack :\n', np.stack((arr1, arr1), axis=1))
# Out:
# hstack :
#  [1 2 3 1 2 3]
# vstack :
#  [[1 2 3]
#  [1 2 3]]
# stack :
#  [[1 2 3]
#  [1 2 3]]
# stack :
#  [[1 1]
#  [2 2]
#  [3 3]]

# %% [markdown]
# ## pandas

# %%
# pandas : dataframe을 이용해 효율적으로 자료 관리 가능
import pandas as pd

patient = [['Kim', 31],
           ['Lee', 23],
           ['Park', 25]]
df = pd.DataFrame(data=patient, columns=['name', 'age'])
df.head()
# Out:
#    name  age
# 0   Kim   31
# 1   Lee   23
# 2  Park   25

# %%
df['name']
# Out:
# 0     Kim
# 1     Lee
# 2    Park
# Name: name, dtype: object

# %% [markdown]
# ## matplotlib

# %%
# matplotlib : 그래프나 이미지 등을 시각화해주는 툴
import matplotlib.pyplot as plt

sine = [np.sin(x) for x in np.arange(0, 4*np.pi, 4*np.pi/40)] # start, end, interval
plt.plot(sine)

# %%
image = np.stack([np.arange(10) for _ in range(10)])
plt.imshow(image, 'gray')

# %% [markdown]
# # 디지털 영상의 기초 이해
# *   Pixel level
# *   Transformation

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Pixel level
# * Add
# * Inverse
# * Threshold

# %%
def plot_with_histogram(imglist, title=None):
  if title:
    assert len(imglist) == len(title)

  for i in range(len(imglist)):
    plt.figure(figsize=(15,7))
    plt.subplot(121)
    plt.imshow(imglist[i], 'gray')
    if title:
      plt.title(title[i])
      
    plt.subplot(122)
    plt.hist(imglist[i].flatten())
    if title:
      plt.title(title[i])
    plt.show()

# %%
img = cv2.imread('/content/drive/My Drive/ComputerVision/coin.png', cv2.IMREAD_GRAYSCALE)
print(img.dtype)
plot_with_histogram([img])
# Out:
# uint8

# %% [markdown]
# ### Add

# %%
# add
img_add = img + 100*np.random.random(size=img.shape)
img_add = np.clip(img_add, 0, 255).astype(np.uint8)
plot_with_histogram([img_add])

# %% [markdown]
# ### Inverse

# %%
# Inverse
img_inv = 255 - img
plot_with_histogram([img_inv])

# %% [markdown]
# ### Threshold

# %%
# Threshold
value = 150
flag = 0

## numpy
if flag:
  img_thres = img.copy()
  img_thres[img < value] = 0
  img_thres[img > value] = 1

## opencv
else:
  # cv2.THRESH_BINARY
  # cv2.THRESH_BINARY_INV
  # cv2.THRESH_TRUNC
  # cv2.THRESH_TOZERO
  # cv2.THRESH_TOZERO_INV
  ret, img_thres = cv2.threshold(img, value, 255, cv2.THRESH_BINARY)

plot_with_histogram([img_thres])

# %%
# adaptive threshold
th2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 15, 2)
th3 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 15, 2)

# Otsu
ret, th4 = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
plot_with_histogram([th2, th3, th4], title=['Mean', 'Gaussian', 'Otsu'])

# %% [markdown]
# ## Transformation
# * Flip (horizontal, vertical)
# * Resize
# * Translate
# * Rotate
# * Shear

# %%
img = cv2.imread('/content/drive/My Drive/ComputerVision/Lenna_color.png', cv2.IMREAD_GRAYSCALE)
print(img.shape)
plt.imshow(img, 'gray')
# Out:
# (512, 512)

# %% [markdown]
# ### Flip

# %%
# flip
img_hflip = img[:,::-1]
img_vflip = img[::-1]

plt.figure(figsize=(10, 10))
plt.subplot(131)
plt.imshow(img, 'gray')
plt.title('original : {}'.format(img.shape))
plt.subplot(132)
plt.imshow(img_hflip, 'gray')
plt.title('horizontal flip : {}'.format(img_hflip.shape))
plt.subplot(133)
plt.imshow(img_vflip, 'gray')
plt.title('vertical flip : {}'.format(img_vflip.shape))
plt.show()

# %% [markdown]
# ### Resize

# %%
# resize
height, width = img.shape
img_shrink = cv2.resize(img, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_AREA)
img_zoom = cv2.resize(img, (width*2, height*2), interpolation=cv2.INTER_CUBIC)

plt.figure(figsize=(10, 10))
plt.subplot(131)
plt.imshow(img, 'gray')
plt.title('original : {}'.format(img.shape))
plt.subplot(132)
plt.imshow(img_shrink, 'gray')
plt.title('shrink : {}'.format(img_shrink.shape))
plt.subplot(133)
plt.imshow(img_zoom, 'gray')
plt.title('zoom : {}'.format(img_zoom.shape))
plt.show()

# %% [markdown]
# ### Translate

# %%
x = np.arange(512)
y = np.arange(512)
xx, yy = np.meshgrid(x, y, sparse=True)

# %%
# translation
# X축으로 50, Y축으로 100
X = 50
Y = 100

M = np.array([[1, 0, X],
              [0, 1, Y]], dtype=np.float32)
img_translate = cv2.warpAffine(img, M, (width, height))

plt.figure(figsize=(10, 10))
plt.subplot(121)
plt.imshow(img, 'gray')
plt.title('original')
plt.subplot(122)
plt.imshow(img_translate, 'gray')
plt.title('after translation')
plt.show()

# %% [markdown]
# ### Rotate

# %%
# rotate
degree = 45
origin = (width/2, height/2)
scale = 1.
M = cv2.getRotationMatrix2D(origin, degree, scale)
img_rotate = cv2.warpAffine(img, M, (width, height))

plt.figure(figsize=(10, 10))
plt.subplot(121)
plt.imshow(img, 'gray')
plt.title('original')
plt.subplot(122)
plt.imshow(img_rotate, 'gray')
plt.title('after rotation')
plt.show()

# %% [markdown]
# ### Shear

# %%
# shear
level = 0.2
M_x = np.array([[1, level, 0],
                [0, 1, 0]], dtype=np.float32)
M_y = np.array([[1, 0, 0],
                [level, 1, 0]], dtype=np.float32)
img_shear_x = cv2.warpAffine(img, M_x, (width, height))
img_shear_y = cv2.warpAffine(img, M_y, (width, height))

plt.figure(figsize=(10, 10))
plt.subplot(131)
plt.imshow(img, 'gray')
plt.title('original')
plt.subplot(132)
plt.imshow(img_shear_x, 'gray')
plt.title('after x shearing')
plt.subplot(133)
plt.imshow(img_shear_y, 'gray')
plt.title('after y shearing')
plt.show()

# %% [markdown]
# ## Filter
# * Blurring
# * Edge detection

# %% [markdown]
# ### Blurring

# %%
kernel_size = 9

# mean filter
img_blur_mean = cv2.blur(img, (kernel_size, kernel_size))

# median filter
img_blur_median = cv2.medianBlur(img, kernel_size)

# gaussian filter
std = 3
img_blur_gaussian = cv2.GaussianBlur(img, (kernel_size, kernel_size), std)
gaussian_filter = cv2.getGaussianKernel(kernel_size, std)
gaussian_filter = np.outer(gaussian_filter, gaussian_filter.T)

plt.figure(figsize=(25, 25))
plt.subplot(151)
plt.imshow(img, 'gray')
plt.title('original')

plt.subplot(152)
plt.imshow(img_blur_mean, 'gray')
plt.title('blurring using mean filter')

plt.subplot(153)
plt.imshow(img_blur_median, 'gray')
plt.title('blurring using median filter')

plt.subplot(154)
plt.imshow(img_blur_gaussian, 'gray')
plt.title('blurring using gaussian filter')
plt.subplot(155)
plt.imshow(gaussian_filter, 'gray')
plt.title('gaussian_filter')
plt.show()

# %% [markdown]
# ### Edge detection

# %%
# sobel
## filter
M_x = np.array([[-1, 0, 1],
                [-2, 0, 2],
                [-1, 0, 1]], dtype=np.float32)
M_y = np.array([[-1, -2, -1],
                [0, 0, 0],
                [1, 2, 1]], dtype=np.float32)
img_sobel_x = cv2.filter2D(img, -1, M_x)
img_sobel_y = cv2.filter2D(img, -1, M_y)

## opencv
# img_sobel_x = cv2.Sobel(img, -1, 1, 0)
# img_sobel_y = cv2.Sobel(img, -1, 0, 1)

# laplacian
img_laplacian = cv2.Laplacian(img, -1)

# canny
thres1, thres2 = 30, 70
img_canny = cv2.Canny(img, thres1, thres2)

plt.figure(figsize=(25, 25))
plt.subplot(161)
plt.imshow(img, 'gray')
plt.title('original')

plt.subplot(162)
plt.imshow(img_sobel_x, 'gray')
plt.title('sobel filter (x)')

plt.subplot(163)
plt.imshow(img_sobel_y, 'gray')
plt.title('sobel filter (y)')

plt.subplot(164)
plt.imshow(img_sobel_x//2+img_sobel_y//2, 'gray')
plt.title('sobel filter (x, y)')

plt.subplot(165)
plt.imshow(img_laplacian, 'gray')
plt.title('laplacial filter')

plt.subplot(166)
plt.imshow(img_canny, 'gray')
plt.title('canny edge')
plt.show()
